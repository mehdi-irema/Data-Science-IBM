# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Mohammad Mahdi Ameri**
# Univeristy Student

# %% [markdown]
# *I am interested in data science because I am good at statistics and I think I can be a successful person if I become a data scientist. Also, I am inspired by my university professor who is a data science expert. Finally, I hope to get good at data science and be able to get the most results out of it.*

# %% [markdown]
# ### Printing a sentence

# %%
print('Hello there!')

# %% [markdown]
#  ---
# > If you're not failing every now and again, it's a sign you're not doing anything very innovative.
#
#  ---
#
# 1. AI Trust
# 2. Model Bias
# 3. Explainability
#
#  ---
#
#  <https://www.ibm.com>
